# %%
import pandas as pd
from prophet import Prophet
import tqdm as notebook_tqdm

df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)
# Out:
# 23:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 23:50:46 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.210097    7.501693    8.887335
# 3266 2017-01-16  8.535122    7.834758    9.213338
# 3267 2017-01-17  8.322549    7.599376    9.027721
# 3268 2017-01-18  8.155179    7.479728    8.836297
# 3269 2017-01-19  8.167136    7.423229    8.839553

# %%
fig1 = m.plot(forecast)
